# %% [markdown]
# # 모든코인 상승장? 하락장?
# > 최고가와 최저가의 차이를 변동폭으로 정의할 때 (시가 + 변동폭)이 최고가 보다 높을 경우 "상승장", 그렇지 않은 경우 "하락장" 문자열을 출력하라.
#
#
# |Key Name|Description|
# |------|---|
# |opeing_price|최근 24시간 내 시작 거래금액|
# |closing_price|최근 24시간 내 마지막 거래금액|
# |min_price|최근 24시간 내 최저 거래금액|
# |max_price|최근 24시간 내 최고 거래금액|

# %%
import requests
import pprint
url = "https://api.bithumb.com/public/ticker/all"
data = requests.get(url).json()['data']
pprint.pprint(data)
# Out:
# {'ABT': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '1.69',
#          'average_price': '301.5135',
#          'buy_price': '300',
#          'closing_price': '300',
#          'max_price': '318',
#          'min_price': '284',
#          'opening_price': '295',
#          'sell_price': '304',
#          'units_traded': '1604181.70701994',
#          'volume_1day': '1604181.70701994',
#          'volume_7day': '10468306.013181080946111547'},
#  'ADA': {'24H_fluctate': '4.5',
#          '24H_fluctate_rate': '4.82',
#          'average_price': '96.1243',
#          'buy_price': '96.6',
#          'closing_price': '97.8',
#          'max_price': '103',
#          'min_price': '91.3',
#          'opening_price': '93.3',
#          'sell_price': '97.8',
#          'units_traded': '6420026.72479554',
#          'volume_1day': '6420026.72479554',
#          'volume_7day': '63763541.49431385'},
#  'AE': {'24H_fluctate': '14',
#         '24H_fluctate_rate': '2.73',
#         'average_price': '533.7587',
#         'buy_price': '522',
#         'closing_price': '525',
#         'max_price': '570',
#         'min_price': '505',
#         'opening_price': '511',
#         'sell_price': '525',
#         'units_traded': '436610.33565147',
#         'volume_1day': '436610.33565147',
#         'volume_7day': '2495921.769023338290864385'},
#  'AMO': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.6409',
#          'buy_price': '0.64',
#          'closing_price': '0.65',
#          'max_price': '0.66',
#          'min_price': '0.61',
#          'opening_price': '0.65',
#          'sell_price': '0.65',
#          'units_traded': '326668979.01267477',
#          'volume_1day': '326668979.01267477',
#          'volume_7day': '3304862623.774824469475093072'},
#  'ANKR': {'24H_fluctate': '0.6',
#           '24H_fluctate_rate': '5.82',
#           'average_price': '10.5523',
#           'buy_price': '10.8',
#           'closing_price': '10.9',
#           'max_price': '11',
#           'min_price': '10.1',
#           'opening_price': '10.3',
#           'sell_price': '10.9',
#           'units_traded': '92676978.31270425',
#           'volume_1day': '92676978.31270425',
#           'volume_7day': '684875542.150600687930143084'},
#  'APIS': {'24H_fluctate': '0.13',
#           '24H_fluctate_rate': '7.83',
#           'average_price': '1.7344',
#           'buy_price': '1.77',
#           'closing_price': '1.79',
#           'max_price': '1.9',
#           'min_price': '1.66',
#           'opening_price': '1.66',
#           'sell_price': '1.79',
#           'units_traded': '65174854.76909579',
#           'volume_1day': '65174854.76909579',
#           'volume_7day': '301045905.719710022513315604'},
#  'ARN': {'24H_fluctate': '13',
#          '24H_fluctate_rate': '2.47',
#          'average_price': '546.053',
#          'buy_price': '534',
#          'closing_price': '538',
#          'max_price': '586',
#          'min_price': '516',
#          'opening_price': '525',
#          'sell_price': '538',
#          'units_traded': '295402.71342498',
#          'volume_1day': '295402.71342498',
#          'volume_7day': '1686988.94843984'},
#  'AUTO': {'24H_fluctate': '0.04',
#           '24H_fluctate_rate': '2.42',
#           'average_price': '1.6689',
#           'buy_price': '1.68',
#           'closing_price': '1.69',
#           'max_price': '1.73',
#           'min_price': '1.62',
#           'opening_price': '1.65',
#           'sell_price': '1.69',
#           'units_traded': '27035088.66305438',
#           'volume_1day': '27035088.66305438',
#           'volume_7day': '317407649.010713603262875436'},
#  'BAT': {'24H_fluctate': '-4',
#          '24H_fluctate_rate': '-1.39',
#          'average_price': '291.6456',
#          'buy_price': '280',
#          'closing_price': '282',
#          'max_price': '305',
#          'min_price': '276',
#          'opening_price': '286',
#          'sell_price': '282',
#          'units_traded': '563412.73472239',
#          'volume_1day': '563412.73472239',
#          'volume_7day': '8724716.058617355292766026'},
#  'BCD': {'24H_fluctate': '294',
#          '24H_fluctate_rate': '15.50',
#          'average_price': '2180.021',
#          'buy_price': '2188',
#          'closing_price': '2190',
#          'max_price': '2367',
#          'min_price': '1872',
#          'opening_price': '1896',
#          'sell_price': '2220',
#          'units_traded': '830556.64292818',
#          'volume_1day': '830556.64292818',
#          'volume_7day': '1595752.33312367'},
#  'BCH': {'24H_fluctate': '28500',
#          '24H_fluctate_rate': '8.27',
#          'average_price': '369008.621',
#          'buy_price': '372900',
#          'closing_price': '372900',
#          'max_price': '393600',
#          'min_price': '338000',
#          'opening_price': '344400',
#          'sell_price': '373300',
#          'units_traded': '38262.81568547',
#          'volume_1day': '38262.81568547',
#          'volume_7day': '215706.11526123'},
#  'BHP': {'24H_fluctate': '19',
#          '24H_fluctate_rate': '1.09',
#          'average_price': '1766.0536',
#          'buy_price': '1750',
#          'closing_price': '1750',
#          'max_price': '1871',
#          'min_price': '1680',
#          'opening_price': '1731',
#          'sell_price': '1753',
#          'units_traded': '710346.89118545',
#          'volume_1day': '710346.89118545',
#          'volume_7day': '1455983.86813679'},
#  'BSV': {'24H_fluctate': '12700',
#          '24H_fluctate_rate': '8.84',
#          'average_price': '151178.4982',
#          'buy_price': '156300',
#          'closing_price': '156300',
#          'max_price': '163600',
#          'min_price': '138400',
#          'opening_price': '143600',
#          'sell_price': '156900',
#          'units_traded': '76681.89322257',
#          'volume_1day': '76681.89322257',
#          'volume_7day': '297231.54979978'},
#  'BTC': {'24H_fluctate': '579000',
#          '24H_fluctate_rate': '4.69',
#          'average_price': '12767058.0501',
#          'buy_price': '12920000',
#          'closing_price': '12920000',
#          'max_price': '13451000',
#          'min_price': '12110000',
#          'opening_price': '12341000',
#          'sell_price': '12925000',
#          'units_traded': '12586.36401402',
#          'volume_1day': '12586.36401402',
#          'volume_7day': '90083.77438996'},
#  'BTG': {'24H_fluctate': '1180',
#          '24H_fluctate_rate': '4.18',
#          'average_price': '29533.7795',
#          'buy_price': '29270',
#          'closing_price': '29380',
#          'max_price': '30800',
#          'min_price': '27800',
#          'opening_price': '28200',
#          'sell_price': '29600',
#          'units_traded': '22666.16340297',
#          'volume_1day': '22666.16340297',
#          'volume_7day': '239926.78475974'},
#  'BTT': {'24H_fluctate': '0.03',
#          '24H_fluctate_rate': '2.23',
#          'average_price': '1.3622',
#          'buy_price': '1.37',
#          'closing_price': '1.37',
#          'max_price': '1.53',
#          'min_price': '1.21',
#          'opening_price': '1.34',
#          'sell_price': '1.38',
#          'units_traded': '363251185.04043238',
#          'volume_1day': '363251185.04043238',
#          'volume_7day': '1521008203.10975152'},
#  'BZNT': {'24H_fluctate': '0.8',
#           '24H_fluctate_rate': '3.61',
#           'average_price': '22.7614',
#           'buy_price': '22.7',
#           'closing_price': '22.9',
#           'max_price': '23.4',
#           'min_price': '22',
#           'opening_price': '22.1',
#           'sell_price': '22.9',
#           'units_traded': '4256222.5547809',
#           'volume_1day': '4256222.5547809',
#           'volume_7day': '88291614.183611064867138655'},
#  'CMT': {'24H_fluctate': '1.6',
#          '24H_fluctate_rate': '2.54',
#          'average_price': '63.7963',
#          'buy_price': '64.1',
#          'closing_price': '64.5',
#          'max_price': '67.7',
#          'min_price': '60.6',
#          'opening_price': '62.9',
#          'sell_price': '64.5',
#          'units_traded': '11696453.57175267',
#          'volume_1day': '11696453.57175267',
#          'volume_7day': '313965872.946254913950271367'},
#  'CON': {'24H_fluctate': '0.3',
#          '24H_fluctate_rate': '2.17',
#          'average_price': '14.0627',
#          'buy_price': '14',
#          'closing_price': '14.1',
#          'max_price': '14.5',
#          'min_price': '13.7',
#          'opening_price': '13.8',
#          'sell_price': '14.1',
#          'units_traded': '141943128.63143798',
#          'volume_1day': '141943128.63143798',
#          'volume_7day': '1186598063.950898126919498287'},
#  'CTXC': {'24H_fluctate': '5',
#           '24H_fluctate_rate': '1.03',
#           'average_price': '498.3886',
#           'buy_price': '488',
#           'closing_price': '488',
#           'max_price': '514',
#           'min_price': '480',
#           'opening_price': '483',
#           'sell_price': '493',
#           'units_traded': '392980.92243165',
#           'volume_1day': '392980.92243165',
#           'volume_7day': '8876824.803646649042605382'},
#  'DAC': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-1.72',
#          'average_price': '5.797',
#          'buy_price': '5.61',
#          'closing_price': '5.69',
#          'max_price': '6.04',
#          'min_price': '5.53',
#          'opening_price': '5.79',
#          'sell_price': '5.69',
#          'units_traded': '25121979.73206067',
#          'volume_1day': '25121979.73206067',
#          'volume_7day': '814393417.803726332286417368'},
#  'DACC': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '0.1647',
#           'buy_price': '0.16',
#           'closing_price': '0.17',
#           'max_price': '0.17',
#           'min_price': '0.15',
#           'opening_price': '0.17',
#           'sell_price': '0.17',
#           'units_traded': '402089007.66819411',
#           'volume_1day': '402089007.66819411',
#           'volume_7day': '2766887748.60924614'},
#  'DASH': {'24H_fluctate': '9400',
#           '24H_fluctate_rate': '6.10',
#           'average_price': '160339.9145',
#           'buy_price': '162500',
#           'closing_price': '163400',
#           'max_price': '170000',
#           'min_price': '149100',
#           'opening_price': '154000',
#           'sell_price': '163400',
#           'units_traded': '1167822.74676835',
#           'volume_1day': '1167822.74676835',
#           'volume_7day': '11365676.17879985'},
#  'ELF': {'24H_fluctate': '5',
#          '24H_fluctate_rate': '3.18',
#          'average_price': '161.5154',
#          'buy_price': '162',
#          'closing_price': '162',
#          'max_price': '170',
#          'min_price': '154',
#          'opening_price': '157',
#          'sell_price': '164',
#          'units_traded': '1080789.46150696',
#          'volume_1day': '1080789.46150696',
#          'volume_7day': '10467822.181007427790253715'},
#  'ENJ': {'24H_fluctate': '-2',
#          '24H_fluctate_rate': '-1.63',
#          'average_price': '120.1445',
#          'buy_price': '119',
#          'closing_price': '120',
#          'max_price': '126',
#          'min_price': '115',
#          'opening_price': '122',
#          'sell_price': '120',
#          'units_traded': '15929888.74468712',
#          'volume_1day': '15929888.74468712',
#          'volume_7day': '69354995.71113197904097732'},
#  'EOS': {'24H_fluctate': '-5',
#          '24H_fluctate_rate': '-0.09',
#          'average_price': '5185.0917',
#          'buy_price': '5120',
#          'closing_price': '5130',
#          'max_price': '5345',
#          'min_price': '4973',
#          'opening_price': '5135',
#          'sell_price': '5130',
#          'units_traded': '2158561.63652559',
#          'volume_1day': '2158561.63652559',
#          'volume_7day': '17638108.41552698'},
#  'ETC': {'24H_fluctate': '330',
#          '24H_fluctate_rate': '5.00',
#          'average_price': '6774.3577',
#          'buy_price': '6910',
#          'closing_price': '6920',
#          'max_price': '7105',
#          'min_price': '6430',
#          'opening_price': '6590',
#          'sell_price': '6930',
#          'units_traded': '111374.78018467',
#          'volume_1day': '111374.78018467',
#          'volume_7day': '804047.59151493814101204'},
#  'ETH': {'24H_fluctate': '5700',
#          '24H_fluctate_rate': '2.12',
#          'average_price': '275340.1535',
#          'buy_price': '274300',
#          'closing_price': '274300',
#          'max_price': '284900',
#          'min_price': '262900',
#          'opening_price': '268600',
#          'sell_price': '274600',
#          'units_traded': '112978.60345833',
#          'volume_1day': '112978.60345833',
#          'volume_7day': '611476.101983507840462711'},
#  'ETHOS': {'24H_fluctate': '4',
#            '24H_fluctate_rate': '2.66',
#            'average_price': '152.2843',
#            'buy_price': '153',
#            'closing_price': '154',
#            'max_price': '160',
#            'min_price': '144',
#            'opening_price': '150',
#            'sell_price': '154',
#            'units_traded': '2753456.47098567',
#            'volume_1day': '2753456.47098567',
#            'volume_7day': '45244660.92263607'},
#  'ETZ': {'24H_fluctate': '10',
#          '24H_fluctate_rate': '3.42',
#          'average_price': '302.9453',
#          'buy_price': '301',
#          'closing_price': '302',
#          'max_price': '318',
#          'min_price': '286',
#          'opening_price': '292',
#          'sell_price': '302',
#          'units_traded': '1221287.4696824',
#          'volume_1day': '1221287.4696824',
#          'volume_7day': '18453308.019423402404599144'},
#  'GNT': {'24H_fluctate': '0.2',
#          '24H_fluctate_rate': '0.26',
#          'average_price': '76.2052',
#          'buy_price': '76',
#          'closing_price': '75.8',
#          'max_price': '80',
#          'min_price': '73.3',
#          'opening_price': '75.6',
#          'sell_price': '77.9',
#          'units_traded': '470720.22154313',
#          'volume_1day': '470720.22154313',
#          'volume_7day': '5928882.503175536012054078'},
#  'GTO': {'24H_fluctate': '0.4',
#          '24H_fluctate_rate': '1.46',
#          'average_price': '27.7067',
#          'buy_price': '27.6',
#          'closing_price': '27.7',
#          'max_price': '29.5',
#          'min_price': '26.3',
#          'opening_price': '27.3',
#          'sell_price': '28.5',
#          'units_traded': '3014031.14007256',
#          'volume_1day': '3014031.14007256',
#          'volume_7day': '27977147.88103324'},
#  'GXC': {'24H_fluctate': '132',
#          '24H_fluctate_rate': '7.23',
#          'average_price': '1920.5244',
#          'buy_price': '1902',
#          'closing_price': '1957',
#          'max_price': '2055',
#          'min_price': '1761',
#          'opening_price': '1825',
#          'sell_price': '1957',
#          'units_traded': '134730.38013304',
#          'volume_1day': '134730.38013304',
#          'volume_7day': '1678380.61065499'},
#  'HC': {'24H_fluctate': '84',
#         '24H_fluctate_rate': '2.11',
#         'average_price': '4182.3971',
#         'buy_price': '4031',
#         'closing_price': '4057',
#         'max_price': '4500',
#         'min_price': '3835',
#         'opening_price': '3973',
#         'sell_price': '4057',
#         'units_traded': '316688.3133668',
#         'volume_1day': '316688.3133668',
#         'volume_7day': '4511729.72621696'},
#  'HDAC': {'24H_fluctate': '0.2',
#           '24H_fluctate_rate': '0.65',
#           'average_price': '30.5906',
#           'buy_price': '30.7',
#           'closing_price': '30.7',
#           'max_price': '32.5',
#           'min_price': '28.8',
#           'opening_price': '30.5',
#           'sell_price': '30.9',
#           'units_traded': '2886811.4598944',
#           'volume_1day': '2886811.4598944',
#           'volume_7day': '34493595.40824786'},
#  'HYC': {'24H_fluctate': '-0.12',
#          '24H_fluctate_rate': '-1.20',
#          'average_price': '10.0075',
#          'buy_price': '9.87',
#          'closing_price': '9.88',
#          'max_price': '10.4',
#          'min_price': '9.73',
#          'opening_price': '10',
#          'sell_price': '9.88',
#          'units_traded': '61201617.89240955',
#          'volume_1day': '61201617.89240955',
#          'volume_7day': '1407913858.706395482'},
#  'ICX': {'24H_fluctate': '11',
#          '24H_fluctate_rate': '3.25',
#          'average_price': '343.221',
#          'buy_price': '343',
#          'closing_price': '349',
#          'max_price': '357',
#          'min_price': '332',
#          'opening_price': '338',
#          'sell_price': '349',
#          'units_traded': '371455.11794941',
#          'volume_1day': '371455.11794941',
#          'volume_7day': '3714190.221219792836388809'},
#  'INS': {'24H_fluctate': '10',
#          '24H_fluctate_rate': '2.29',
#          'average_price': '455.6071',
#          'buy_price': '443',
#          'closing_price': '446',
#          'max_price': '488',
#          'min_price': '426',
#          'opening_price': '436',
#          'sell_price': '446',
#          'units_traded': '338279.82450741',
#          'volume_1day': '338279.82450741',
#          'volume_7day': '8541419.0245807144'},
#  'IOST': {'24H_fluctate': '0.4',
#           '24H_fluctate_rate': '3.47',
#           'average_price': '11.9702',
#           'buy_price': '11.9',
#           'closing_price': '11.9',
#           'max_price': '13',
#           'min_price': '11',
#           'opening_price': '11.5',
#           'sell_price': '12.1',
#           'units_traded': '4409503.10451781',
#           'volume_1day': '4409503.10451781',
#           'volume_7day': '39888928.57445144034281569'},
#  'ITC': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-0.28',
#          'average_price': '355.6417',
#          'buy_price': '347',
#          'closing_price': '347',
#          'max_price': '375',
#          'min_price': '323',
#          'opening_price': '348',
#          'sell_price': '350',
#          'units_traded': '1503975.48968889',
#          'volume_1day': '1503975.48968889',
#          'volume_7day': '22381523.302299064799285311'},
#  'KNC': {'24H_fluctate': '10',
#          '24H_fluctate_rate': '4.60',
#          'average_price': '224.4624',
#          'buy_price': '226',
#          'closing_price': '227',
#          'max_price': '247',
#          'min_price': '213',
#          'opening_price': '217',
#          'sell_price': '229',
#          'units_traded': '603420.69695415',
#          'volume_1day': '603420.69695415',
#          'volume_7day': '5461775.16999698425300172'},
#  'LBA': {'24H_fluctate': '-1',
#          '24H_fluctate_rate': '-3.22',
#          'average_price': '31.1456',
#          'buy_price': '30',
#          'closing_price': '30',
#          'max_price': '32.3',
#          'min_price': '29.9',
#          'opening_price': '31',
#          'sell_price': '30.3',
#          'units_traded': '9377209.24289058',
#          'volume_1day': '9377209.24289058',
#          'volume_7day': '96826358.89663059765145354'},
#  'LINK': {'24H_fluctate': '34',
#           '24H_fluctate_rate': '0.74',
#           'average_price': '4676.0676',
#           'buy_price': '4600',
#           'closing_price': '4600',
#           'max_price': '4940',
#           'min_price': '4434',
#           'opening_price': '4566',
#           'sell_price': '4622',
#           'units_traded': '355608.66816971',
#           'volume_1day': '355608.66816971',
#           'volume_7day': '5124476.873040540485095644'},
#  'LOOM': {'24H_fluctate': '1.2',
#           '24H_fluctate_rate': '1.37',
#           'average_price': '87.2781',
#           'buy_price': '88.6',
#           'closing_price': '88.6',
#           'max_price': '91.5',
#           'min_price': '81.9',
#           'opening_price': '87.4',
#           'sell_price': '90.5',
#           'units_traded': '475660.87968112',
#           'volume_1day': '475660.87968112',
#           'volume_7day': '4411733.146080573999395522'},
#  'LRC': {'24H_fluctate': '1.4',
#          '24H_fluctate_rate': '1.92',
#          'average_price': '73.2199',
#          'buy_price': '73',
#          'closing_price': '74',
#          'max_price': '80.8',
#          'min_price': '70.1',
#          'opening_price': '72.6',
#          'sell_price': '74.9',
#          'units_traded': '580242.74778488',
#          'volume_1day': '580242.74778488',
#          'volume_7day': '5610041.087529428809595789'},
#  'LTC': {'24H_fluctate': '200',
#          '24H_fluctate_rate': '0.18',
#          'average_price': '108575.1343',
#          'buy_price': '107400',
#          'closing_price': '107500',
#          'max_price': '112200',
#          'min_price': '103500',
#          'opening_price': '107300',
#          'sell_price': '107700',
#          'units_traded': '21638.666598',
#          'volume_1day': '21638.666598',
#          'volume_7day': '176029.71980704'},
#  'MCO': {'24H_fluctate': '60',
#          '24H_fluctate_rate': '0.99',
#          'average_price': '6058.9587',
#          'buy_price': '6070',
#          'closing_price': '6090',
#          'max_price': '6300',
#          'min_price': '5790',
#          'opening_price': '6030',
#          'sell_price': '6150',
#          'units_traded': '43821.71594906',
#          'volume_1day': '43821.71594906',
#          'volume_7day': '256263.89426217'},
#  'MITH': {'24H_fluctate': '0.8',
#           '24H_fluctate_rate': '1.70',
#           'average_price': '47.0562',
#           'buy_price': '47.2',
#           'closing_price': '47.6',
#           'max_price': '49.4',
#           'min_price': '45.4',
#           'opening_price': '46.8',
#           'sell_price': '47.8',
#           'units_traded': '3215645.70320772',
#           'volume_1day': '3215645.70320772',
#           'volume_7day': '15600317.018092870012514476'},
#  'MIX': {'24H_fluctate': '-0.7',
#          '24H_fluctate_rate': '-1.04',
#          'average_price': '67.1717',
#          'buy_price': '66.7',
#          'closing_price': '66.6',
#          'max_price': '69.6',
#          'min_price': '64.3',
#          'opening_price': '67.3',
#          'sell_price': '67',
#          'units_traded': '2813500.91355097',
#          'volume_1day': '2813500.91355097',
#          'volume_7day': '40476246.122099805620073668'},
#  'MTL': {'24H_fluctate': '155',
#          '24H_fluctate_rate': '8.01',
#          'average_price': '2072.0061',
#          'buy_price': '2091',
#          'closing_price': '2090',
#          'max_price': '2313',
#          'min_price': '1877',
#          'opening_price': '1935',
#          'sell_price': '2113',
#          'units_traded': '138497.89692698',
#          'volume_1day': '138497.89692698',
#          'volume_7day': '637960.44021716'},
#  'NPXS': {'24H_fluctate': '0.05',
#           '24H_fluctate_rate': '6.84',
#           'average_price': '0.7752',
#           'buy_price': '0.76',
#           'closing_price': '0.78',
#           'max_price': '0.82',
#           'min_price': '0.71',
#           'opening_price': '0.73',
#           'sell_price': '0.78',
#           'units_traded': '538858527.2948872',
#           'volume_1day': '538858527.2948872',
#           'volume_7day': '3225789295.965232208350640193'},
#  'OCN': {'24H_fluctate': '0.13',
#          '24H_fluctate_rate': '4.12',
#          'average_price': '3.2512',
#          'buy_price': '3.23',
#          'closing_price': '3.28',
#          'max_price': '3.46',
#          'min_price': '3.09',
#          'opening_price': '3.15',
#          'sell_price': '3.28',
#          'units_traded': '13187218.50887508',
#          'volume_1day': '13187218.50887508',
#          'volume_7day': '149067170.878134292031302212'},
#  'OMG': {'24H_fluctate': '20',
#          '24H_fluctate_rate': '1.07',
#          'average_price': '1879.2865',
#          'buy_price': '1862',
#          'closing_price': '1877',
#          'max_price': '1960',
#          'min_price': '1774',
#          'opening_price': '1857',
#          'sell_price': '1875',
#          'units_traded': '544756.16976232',
#          'volume_1day': '544756.16976232',
#          'volume_7day': '3234293.499947474251058524'},
#  'ORBS': {'24H_fluctate': '0',
#           '24H_fluctate_rate': '0.00',
#           'average_price': '29.7352',
#           'buy_price': '29.5',
#           'closing_price': '29.6',
#           'max_price': '31',
#           'min_price': '28.6',
#           'opening_price': '29.6',
#           'sell_price': '29.6',
#           'units_traded': '14573480.36418046',
#           'volume_1day': '14573480.36418046',
#           'volume_7day': '127868738.703261028319004324'},
#  'PAY': {'24H_fluctate': '11',
#          '24H_fluctate_rate': '4.15',
#          'average_price': '271.1646',
#          'buy_price': '272',
#          'closing_price': '276',
#          'max_price': '290',
#          'min_price': '255',
#          'opening_price': '265',
#          'sell_price': '277',
#          'units_traded': '213429.25203513',
#          'volume_1day': '213429.25203513',
#          'volume_7day': '3345705.82471745684417128'},
#  'PIVX': {'24H_fluctate': '219',
#           '24H_fluctate_rate': '12.31',
#           'average_price': '1975.8748',
#           'buy_price': '1933',
#           'closing_price': '1997',
#           'max_price': '2228',
#           'min_price': '1692',
#           'opening_price': '1778',
#           'sell_price': '1990',
#           'units_traded': '77842.6318423',
#           'volume_1day': '77842.6318423',
#           'volume_7day': '669534.86037417'},
#  'PLY': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.73',
#          'average_price': '13.7293',
#          'buy_price': '13.6',
#          'closing_price': '13.7',
#          'max_price': '14.4',
#          'min_price': '13.1',
#          'opening_price': '13.6',
#          'sell_price': '13.7',
#          'units_traded': '39523881.84699597',
#          'volume_1day': '39523881.84699597',
#          'volume_7day': '307998775.595956902'},
#  'POLY': {'24H_fluctate': '5.8',
#           '24H_fluctate_rate': '8.95',
#           'average_price': '75.3717',
#           'buy_price': '70.5',
#           'closing_price': '70.6',
#           'max_price': '88',
#           'min_price': '62.1',
#           'opening_price': '64.8',
#           'sell_price': '70.9',
#           'units_traded': '16918330.57835689',
#           'volume_1day': '16918330.57835689',
#           'volume_7day': '40447721.623914419365097854'},
#  'POWR': {'24H_fluctate': '1.7',
#           '24H_fluctate_rate': '1.72',
#           'average_price': '97.9666',
#           'buy_price': '97.6',
#           'closing_price': '100',
#           'max_price': '103',
#           'min_price': '92',
#           'opening_price': '98.3',
#           'sell_price': '99.8',
#           'units_traded': '904891.11027166',
#           'volume_1day': '904891.11027166',
#           'volume_7day': '7585715.80974943'},
#  'PPT': {'24H_fluctate': '72',
#          '24H_fluctate_rate': '2.12',
#          'average_price': '3438.336',
#          'buy_price': '3419',
#          'closing_price': '3454',
#          'max_price': '3646',
#          'min_price': '3169',
#          'opening_price': '3382',
#          'sell_price': '3454',
#          'units_traded': '126519.96022431',
#          'volume_1day': '126519.96022431',
#          'volume_7day': '1889230.03621142'},
#  'PST': {'24H_fluctate': '17',
#          '24H_fluctate_rate': '12.97',
#          'average_price': '145.1561',
#          'buy_price': '147',
#          'closing_price': '148',
#          'max_price': '157',
#          'min_price': '126',
#          'opening_price': '131',
#          'sell_price': '148',
#          'units_traded': '5171712.10742081',
#          'volume_1day': '5171712.10742081',
#          'volume_7day': '21545537.794964452474168705'},
#  'QTUM': {'24H_fluctate': '188',
#           '24H_fluctate_rate': '4.99',
#           'average_price': '3930.7138',
#           'buy_price': '3936',
#           'closing_price': '3950',
#           'max_price': '4152',
#           'min_price': '3691',
#           'opening_price': '3762',
#           'sell_price': '3950',
#           'units_traded': '458734.16720007',
#           'volume_1day': '458734.16720007',
#           'volume_7day': '3665344.03463717'},
#  'RDN': {'24H_fluctate': '100',
#          '24H_fluctate_rate': '10.76',
#          'average_price': '994.6134',
#          'buy_price': '1029',
#          'closing_price': '1029',
#          'max_price': '1116',
#          'min_price': '861',
#          'opening_price': '929',
#          'sell_price': '1030',
#          'units_traded': '360921.31942998',
#          'volume_1day': '360921.31942998',
#          'volume_7day': '1982851.885065818380735272'},
#  'REP': {'24H_fluctate': '1230',
#          '24H_fluctate_rate': '6.66',
#          'average_price': '20608.2329',
#          'buy_price': '19760',
#          'closing_price': '19690',
#          'max_price': '24700',
#          'min_price': '18030',
#          'opening_price': '18460',
#          'sell_price': '19990',
#          'units_traded': '61012.7397185',
#          'volume_1day': '61012.7397185',
#          'volume_7day': '185764.949367004532677142'},
#  'RNT': {'24H_fluctate': '0.4',
#          '24H_fluctate_rate': '0.96',
#          'average_price': '41.751',
#          'buy_price': '41.7',
#          'closing_price': '41.8',
#          'max_price': '43.9',
#          'min_price': '40.5',
#          'opening_price': '41.4',
#          'sell_price': '41.8',
#          'units_traded': '2144949.72473142',
#          'volume_1day': '2144949.72473142',
#          'volume_7day': '30037427.941398959215133828'},
#  'ROM': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '0.0446',
#          'buy_price': '0.04',
#          'closing_price': '0.05',
#          'max_price': '0.05',
#          'min_price': '0.04',
#          'opening_price': '0.05',
#          'sell_price': '0.05',
#          'units_traded': '1198294173.46198',
#          'volume_1day': '1198294173.46198',
#          'volume_7day': '19408414494.612640000000000003'},
#  'SALT': {'24H_fluctate': '-1',
#           '24H_fluctate_rate': '-0.47',
#           'average_price': '212.25',
#           'buy_price': '210',
#           'closing_price': '210',
#           'max_price': '228',
#           'min_price': '203',
#           'opening_price': '211',
#           'sell_price': '212',
#           'units_traded': '417635.82714619',
#           'volume_1day': '417635.82714619',
#           'volume_7day': '2747271.66745264'},
#  'SNT': {'24H_fluctate': '1.1',
#          '24H_fluctate_rate': '4.60',
#          'average_price': '24.811',
#          'buy_price': '25',
#          'closing_price': '25',
#          'max_price': '26.1',
#          'min_price': '23.7',
#          'opening_price': '23.9',
#          'sell_price': '25.4',
#          'units_traded': '5023965.0171606',
#          'volume_1day': '5023965.0171606',
#          'volume_7day': '53603317.09536821656894206'},
#  'STEEM': {'24H_fluctate': '13',
#            '24H_fluctate_rate': '3.32',
#            'average_price': '396.2825',
#            'buy_price': '398',
#            'closing_price': '404',
#            'max_price': '412',
#            'min_price': '375',
#            'opening_price': '391',
#            'sell_price': '403',
#            'units_traded': '610606.9447111',
#            'volume_1day': '610606.9447111',
#            'volume_7day': '12068566.70007131'},
#  'STRAT': {'24H_fluctate': '117',
#            '24H_fluctate_rate': '8.49',
#            'average_price': '1481.711',
#            'buy_price': '1473',
#            'closing_price': '1494',
#            'max_price': '1600',
#            'min_price': '1351',
#            'opening_price': '1377',
#            'sell_price': '1493',
#            'units_traded': '256407.17084282',
#            'volume_1day': '256407.17084282',
#            'volume_7day': '1708889.51938857'},
#  'THETA': {'24H_fluctate': '1',
#            '24H_fluctate_rate': '0.89',
#            'average_price': '114.6952',
#            'buy_price': '113',
#            'closing_price': '113',
#            'max_price': '122',
#            'min_price': '110',
#            'opening_price': '112',
#            'sell_price': '115',
#            'units_traded': '728887.19326316',
#            'volume_1day': '728887.19326316',
#            'volume_7day': '6062414.556496666985828777'},
#  'TMTG': {'24H_fluctate': '0.04',
#           '24H_fluctate_rate': '1.86',
#           'average_price': '2.1829',
#           'buy_price': '2.19',
#           'closing_price': '2.19',
#           'max_price': '2.27',
#           'min_price': '2.07',
#           'opening_price': '2.15',
#           'sell_price': '2.2',
#           'units_traded': '48665948.84424638',
#           'volume_1day': '48665948.84424638',
#           'volume_7day': '282805037.835342867958841878'},
#  'TRUE': {'24H_fluctate': '9',
#           '24H_fluctate_rate': '1.69',
#           'average_price': '553.931',
#           'buy_price': '539',
#           'closing_price': '539',
#           'max_price': '598',
#           'min_price': '515',
#           'opening_price': '530',
#           'sell_price': '540',
#           'units_traded': '542108.03560184',
#           'volume_1day': '542108.03560184',
#           'volume_7day': '4510537.440798785681782811'},
#  'TRX': {'24H_fluctate': '0.09',
#          '24H_fluctate_rate': '0.34',
#          'average_price': '29.3709',
#          'buy_price': '29',
#          'closing_price': '29.2',
#          'max_price': '30.3',
#          'min_price': '28.4',
#          'opening_price': '29.1',
#          'sell_price': '29.2',
#          'units_traded': '72664698.25116818',
#          'volume_1day': '72664698.25116818',
#          'volume_7day': '572476830.28145638'},
#  'VALOR': {'24H_fluctate': '142',
#            '24H_fluctate_rate': '5.79',
#            'average_price': '2559.866',
#            'buy_price': '2534',
#            'closing_price': '2592',
#            'max_price': '2696',
#            'min_price': '2409',
#            'opening_price': '2450',
#            'sell_price': '2575',
#            'units_traded': '103255.7685675',
#            'volume_1day': '103255.7685675',
#            'volume_7day': '1148091.843767059660038435'},
#  'VET': {'24H_fluctate': '0.24',
#          '24H_fluctate_rate': '3.30',
#          'average_price': '7.4292',
#          'buy_price': '7.5',
#          'closing_price': '7.51',
#          'max_price': '7.78',
#          'min_price': '7.19',
#          'opening_price': '7.27',
#          'sell_price': '7.6',
#          'units_traded': '14138202.21987113',
#          'volume_1day': '14138202.21987113',
#          'volume_7day': '138042954.601061040157174805'},
#  'WAVES': {'24H_fluctate': '493',
#            '24H_fluctate_rate': '23.01',
#            'average_price': '2735.7155',
#            'buy_price': '2615',
#            'closing_price': '2635',
#            'max_price': '3250',
#            'min_price': '2075',
#            'opening_price': '2142',
#            'sell_price': '2635',
#            'units_traded': '812050.06690782',
#            'volume_1day': '812050.06690782',
#            'volume_7day': '1411227.09211465'},
#  'WAX': {'24H_fluctate': '3.2',
#          '24H_fluctate_rate': '5.07',
#          'average_price': '64.3688',
#          'buy_price': '65.1',
#          'closing_price': '66.2',
#          'max_price': '70',
#          'min_price': '61.9',
#          'opening_price': '63',
#          'sell_price': '66.2',
#          'units_traded': '1884968.77419123',
#          'volume_1day': '1884968.77419123',
#          'volume_7day': '17552832.82818612'},
#  'WET': {'24H_fluctate': '-0.1',
#          '24H_fluctate_rate': '-0.66',
#          'average_price': '15.2688',
#          'buy_price': '15',
#          'closing_price': '15',
#          'max_price': '15.8',
#          'min_price': '14.8',
#          'opening_price': '15.1',
#          'sell_price': '15.1',
#          'units_traded': '11675541.77764334',
#          'volume_1day': '11675541.77764334',
#          'volume_7day': '132565492.539712025431120464'},
#  'WTC': {'24H_fluctate': '51',
#          '24H_fluctate_rate': '1.97',
#          'average_price': '2753.6223',
#          'buy_price': '2594',
#          'closing_price': '2630',
#          'max_price': '3105',
#          'min_price': '2548',
#          'opening_price': '2579',
#          'sell_price': '2651',
#          'units_traded': '232279.37611654',
#          'volume_1day': '232279.37611654',
#          'volume_7day': '5305625.422620448284851752'},
#  'XEM': {'24H_fluctate': '2.1',
#          '24H_fluctate_rate': '2.14',
#          'average_price': '98.5598',
#          'buy_price': '98.6',
#          'closing_price': '100',
#          'max_price': '104',
#          'min_price': '92.7',
#          'opening_price': '97.9',
#          'sell_price': '100',
#          'units_traded': '1093749.37376868',
#          'volume_1day': '1093749.37376868',
#          'volume_7day': '12260840.54910163'},
#  'XLM': {'24H_fluctate': '2',
#          '24H_fluctate_rate': '1.78',
#          'average_price': '112.3676',
#          'buy_price': '112',
#          'closing_price': '114',
#          'max_price': '117',
#          'min_price': '107',
#          'opening_price': '112',
#          'sell_price': '114',
#          'units_traded': '2728869.46953372',
#          'volume_1day': '2728869.46953372',
#          'volume_7day': '23193027.30963126'},
#  'XMR': {'24H_fluctate': '3350',
#          '24H_fluctate_rate': '3.41',
#          'average_price': '97092.2586',
#          'buy_price': '101000',
#          'closing_price': '101400',
#          'max_price': '107700',
#          'min_price': '90300',
#          'opening_price': '98050',
#          'sell_price': '101600',
#          'units_traded': '3650938.31712706',
#          'volume_1day': '3650938.31712706',
#          'volume_7day': '17505935.039810047431'},
#  'XRP': {'24H_fluctate': '0',
#          '24H_fluctate_rate': '0.00',
#          'average_price': '379.0101',
#          'buy_price': '376',
#          'closing_price': '377',
#          'max_price': '391',
#          'min_price': '369',
#          'opening_price': '377',
#          'sell_price': '377',
#          'units_traded': '85646883.49827815',
#          'volume_1day': '85646883.49827815',
#          'volume_7day': '649672379.26907226'},
#  'XVG': {'24H_fluctate': '0.1',
#          '24H_fluctate_rate': '0.67',
#          'average_price': '14.7085',
#          'buy_price': '14.7',
#          'closing_price': '15',
#          'max_price': '15.7',
#          'min_price': '13.9',
#          'opening_price': '14.9',
#          'sell_price': '15',
#          'units_traded': '1718658.81202629',
#          'volume_1day': '1718658.81202629',
#          'volume_7day': '21726162.38678206'},
#  'ZEC': {'24H_fluctate': '3100',
#          '24H_fluctate_rate': '2.98',
#          'average_price': '105195.8248',
#          'buy_price': '106500',
#          'closing_price': '106800',
#          'max_price': '113300',
#          'min_price': '96200',
#          'opening_price': '103700',
#          'sell_price': '106800',
#          'units_traded': '2104.43454529',
#          'volume_1day': '2104.43454529',
#          'volume_7day': '15717.40120851'},
#  'ZIL': {'24H_fluctate': '0.8',
#          '24H_fluctate_rate': '4.90',
#          'average_price': '16.9715',
#          'buy_price': '17',
#          'closing_price': '17.1',
#          'max_price': '17.5',
#          'min_price': '16.3',
#          'opening_price': '16.3',
#          'sell_price': '17.1',
#          'units_traded': '7188939.63675369',
#          'volume_1day': '7188939.63675369',
#          'volume_7day': '61778027.250081790174'},
#  'ZRX': {'24H_fluctate': '49',
#          '24H_fluctate_rate': '18.84',
#          'average_price': '304.2783',
#          'buy_price': '307',
#          'closing_price': '309',
#          'max_price': '328',
#          'min_price': '256',
#          'opening_price': '260',
#          'sell_price': '311',
#          'units_traded': '1665508.77194342',
#          'volume_1day': '1665508.77194342',
#          'volume_7day': '4528852.484931593980106194'},
#  'date': '1563252714415'}

# %%
for key, value in data.items():
    if key == 'date':
        continue
    if float(value['opening_price']) + float(value['max_price']) - float(value['min_price']) > float(value['max_price']):
        print(f'{key}: 상승장')
    else:
        print(f'{key}: 하락장')
# Out:
# BTC: 상승장
# ETH: 상승장
# DASH: 상승장
# LTC: 상승장
# ETC: 상승장
# XRP: 상승장
# BCH: 상승장
# XMR: 상승장
# ZEC: 상승장
# QTUM: 상승장
# BTG: 상승장
# EOS: 상승장
# ICX: 상승장
# VET: 상승장
# TRX: 상승장
# ELF: 상승장
# MITH: 상승장
# MCO: 상승장
# OMG: 상승장
# KNC: 상승장
# GNT: 상승장
# ZIL: 하락장
# ETHOS: 상승장
# PAY: 상승장
# WAX: 상승장
# POWR: 상승장
# LRC: 상승장
# GTO: 상승장
# STEEM: 상승장
# STRAT: 상승장
# ZRX: 상승장
# REP: 상승장
# AE: 상승장
# XEM: 상승장
# SNT: 상승장
# ADA: 상승장
# PPT: 상승장
# CTXC: 상승장
# CMT: 상승장
# THETA: 상승장
# WTC: 상승장
# ITC: 상승장
# TRUE: 상승장
# ABT: 상승장
# RNT: 상승장
# PLY: 상승장
# WAVES: 상승장
# LINK: 상승장
# ENJ: 상승장
# PST: 상승장
# SALT: 상승장
# RDN: 상승장
# LOOM: 상승장
# PIVX: 상승장
# INS: 상승장
# BCD: 상승장
# BZNT: 상승장
# XLM: 상승장
# OCN: 상승장
# BSV: 상승장
# TMTG: 상승장
# BAT: 상승장
# WET: 상승장
# XVG: 상승장
# IOST: 상승장
# POLY: 상승장
# HC: 상승장
# ROM: 상승장
# AMO: 상승장
# ETZ: 상승장
# ARN: 상승장
# APIS: 하락장
# MTL: 상승장
# DACC: 상승장
# DAC: 상승장
# BHP: 상승장
# BTT: 상승장
# HDAC: 상승장
# NPXS: 상승장
# AUTO: 상승장
# GXC: 상승장
# ORBS: 상승장
# VALOR: 상승장
# CON: 상승장
# ANKR: 상승장
# MIX: 상승장
# HYC: 상승장
# LBA: 상승장

# %% [markdown]
# # 평균점수
# > 다음 딕셔너리에서 평균 점수를 출력하라

# %%
student = {'python':80, 'algorithm':78, 'django':95, 'flask':80}

# %%
score = 0
for value in student.values():
    score += value
print(score/len(student))
# Out:
# 83.25

# %% [markdown]
# # 혈액형
# > 학생들의 혈액형(A,B,O,AB)에 대한 데이터가 리스트에 들어있다. 각 혈액형이 몇명인지 딕셔너리를 만들어 출력하라

# %%
blood = ['A','A','B','O','A','B','A','AB','AB','O','A','O','AB','O']

# %%
blood_dict = {'A': 0, 'B': 0, 'AB': 0, 'O': 0}
for blood_type in blood:
    if blood_type == 'A':
        blood_dict['A'] += 1
    elif blood_type == 'B':
        blood_dict['B'] += 1
    elif blood_type == 'AB':
        blood_dict['AB'] += 1
    else:
        blood_dict['O'] += 1
print(blood_dict)
# Out:
# {'A': 5, 'B': 2, 'AB': 3, 'O': 4}

# %% [markdown]
# # UBD
# > movies는 영화제목이 key로 누적관객수가 value인 딕셔너리이다.
# >
# > 자전차왕 엄복동의 누적관객수는 172212명이고 172212명을 1UBD라고 할때 80UBD를 넘지 못하는 영화를 출력하라.

# %%
movies = {
    "7번방의선물":12811206,
    "괴물":13019740,
    "국제시장":14257115,
    "극한직업":16261018,
    "도둑들":12983330,
    "명량":17613682,
    "베테랑":13414009,
    "신과함께-죄와벌":14410754,
    "아바타":13624328,
    "어벤져스:엔드게임":13901423,
}

# %%
UBD = 172212
for key in movies:
    if movies[key] < 80*UBD:
        print(key)
# Out:
# 7번방의선물
# 괴물
# 도둑들
# 베테랑
# 아바타
